# %%
import pandas as pd
import numpy as np
import os

# %%
movie_data=pd.read_csv('data/movies.csv')
rating_data=pd.read_csv('data/ratings.csv')
movie_link_data=pd.read_csv('data/links.csv')
tag_data=pd.read_csv('data/tags.csv')

# %%
print(f'shape of MOVIE dataset is',movie_data.shape)
print("-----------------------------------------")
print(f'unique movieid no.',movie_data['movieId'].nunique())
print("-----------------------------------------")
print(movie_data.isnull().sum())
print("-----------------------------------------")
print(movie_data.describe())
print("-----------------------------------------")
movie_data.head()
# Out:
# shape of MOVIE dataset is (87585, 3)
# -----------------------------------------
# unique movieid no. 87585
# -----------------------------------------
# movieId    0
# title      0
# genres     0
# dtype: int64
# -----------------------------------------
#              movieId
# count   87585.000000
# mean   157651.365519
# std     79013.402099
# min         1.000000
# 25%    112657.000000
# 50%    165741.000000
# 75%    213203.000000
# max    292757.000000
# -----------------------------------------
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
print(f'shape of MOVIE dataset is',rating_data.shape)
print("-----------------------------------------")
print(f'unique movieid no.',rating_data['movieId'].nunique())
print("-----------------------------------------")
print(rating_data.isnull().sum())
print("-----------------------------------------")
print(rating_data.describe())
print("-----------------------------------------")
rating_data.head()
# Out:
# shape of MOVIE dataset is (32000204, 4)
# -----------------------------------------
# unique movieid no. 84432
# -----------------------------------------
# userId       0
# movieId      0
# rating       0
# timestamp    0
# dtype: int64
# -----------------------------------------
#              userId       movieId        rating     timestamp
# count  3.200020e+07  3.200020e+07  3.200020e+07  3.200020e+07
# mean   1.002785e+05  2.931861e+04  3.540396e+00  1.275241e+09
# std    5.794905e+04  5.095816e+04  1.058986e+00  2.561630e+08
# min    1.000000e+00  1.000000e+00  5.000000e-01  7.896520e+08
# 25%    5.005300e+04  1.233000e+03  3.000000e+00  1.051012e+09
# 50%    1.002970e+05  3.452000e+03  3.500000e+00  1.272622e+09
# 75%    1.504510e+05  4.419900e+04  4.000000e+00  1.503158e+09
# max    2.009480e+05  2.927570e+05  5.000000e+00  1.697164e+09
# -----------------------------------------
#    userId  movieId  rating  timestamp
# 0       1       17     4.0  944249077
# 1       1       25     1.0  944250228
# 2       1       29     2.0  943230976
# 3       1       30     5.0  944249077
# 4       1       32     5.0  943228858

# %%
print(f'shape of MOVIE dataset is',tag_data.shape)
print("-----------------------------------------")
print(f'unique movieid no.',tag_data['movieId'].nunique())
print("-----------------------------------------")
print(tag_data.isnull().sum())
print("-----------------------------------------")
print(tag_data.describe())
print("-----------------------------------------")
tag_data.head()
# Out:
# shape of MOVIE dataset is (2000072, 4)
# -----------------------------------------
# unique movieid no. 51323
# -----------------------------------------
# userId        0
# movieId       0
# tag          17
# timestamp     0
# dtype: int64
# -----------------------------------------
#              userId       movieId     timestamp
# count  2.000072e+06  2.000072e+06  2.000072e+06
# mean   8.192859e+04  7.189326e+04  1.528914e+09
# std    3.810650e+04  7.480379e+04  1.290835e+08
# min    2.200000e+01  1.000000e+00  1.135429e+09
# 25%    6.841300e+04  4.011000e+03  1.473615e+09
# 50%    7.821300e+04  5.232800e+04  1.574071e+09
# 75%    1.036980e+05  1.222940e+05  1.614740e+09
# max    1.622790e+05  2.926290e+05  1.697155e+09
# -----------------------------------------
#    userId  movieId          tag   timestamp
# 0      22    26479  Kevin Kline  1583038886
# 1      22    79592     misogyny  1581476297
# 2      22   247150   acrophobia  1622483469
# 3      34     2174        music  1249808064
# 4      34     2174        weird  1249808102

# %%
tag_data.dropna(inplace=True,axis=0)
print(f'shape of tag data',tag_data.shape)
# Out:
# shape of tag data (2000055, 4)

# %%
tags_grouped = tag_data.groupby('movieId')['tag'].agg(
    tags=lambda x: " ".join(x),
    tag_count='count'
).reset_index()

# %%
tags_grouped
# Out:
#        movieId                                               tags  tag_count
# 0            1  children Disney animation children Disney Disn...       1230
# 1            2  Robin Williams fantasy Robin Williams time tra...        573
# 2            3  comedinha de velhinhos engraÃƒÂ§ada comedinha ...         23
# 3            4  characters slurs based on novel or book chick ...         12
# 4            5  Fantasy pregnancy remake family Steve Martin s...         64
# ...        ...                                                ...        ...
# 51318   292143  Cadaqués catalonia China housing estate husban...         12
# 51319   292349                              politically incorrect          1
# 51320   292371                                       Stephen King          1
# 51321   292597                            artificial intelligence          1
# 51322   292629        documentary filmmaking family relationships          2
#
# [51323 rows x 3 columns]

# %%
movie_rating = rating_data.groupby('movieId')['rating'].agg(['mean','count']).reset_index()
movie_rating.columns = ['movieId','average_rating','rating_count']
movie_rating.head()
# Out:
#    movieId  average_rating  rating_count
# 0        1        3.897438         68997
# 1        2        3.275758         28904
# 2        3        3.139447         13134
# 3        4        2.845331          2806
# 4        5        3.059602         13154

# %% [markdown]
# ### Merging movie_data, movie_rating and tags_grouped

# %%
merged_data = pd.merge(movie_data, movie_rating, on='movieId', how='inner')

final_dataset = pd.merge(merged_data, tags_grouped, on='movieId', how='inner')

final_dataset.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres  average_rating  rating_count  \
# 0  Adventure|Animation|Children|Comedy|Fantasy        3.897438         68997
# 1                   Adventure|Children|Fantasy        3.275758         28904
# 2                               Comedy|Romance        3.139447         13134
# 3                         Comedy|Drama|Romance        2.845331          2806
# 4                                       Comedy        3.059602         13154
#
#                                                 tags  tag_count
# 0  children Disney animation children Disney Disn...       1230
# 1  Robin Williams fantasy Robin Williams time tra...        573
# 2  comedinha de velhinhos engraÃƒÂ§ada comedinha ...         23
# 3  characters slurs based on novel or book chick ...         12
# 4  Fantasy pregnancy remake family Steve Martin s...         64

# %%
final_dataset['year'] = final_dataset['title'].str.extract(r'\((\d{4})\)')
final_dataset['title'] = final_dataset['title'].str.replace(r'\(\d{4}\)','', regex=True)
final_dataset['popularity_score'] = final_dataset['rating_count'] * np.log(final_dataset['average_rating'])
print(final_dataset.shape)
# Out:
# (48170, 9)

# %%
# final_dataset['genres'] = final_dataset['genres'].str.replace('|',' ', regex=False)
# final_dataset['genres'] =final_dataset['genres'] .str.lower()
# final_dataset['tags'] = final_dataset['tags'].str.lower()
# final_dataset['features'] = final_dataset['genres'] + " " + final_dataset['tags']
# final_dataset=final_dataset.drop(columns=['tags','genres'])

# %%
# final_dataset = final_dataset[final_dataset['tag_count'] > 2]
final_dataset = final_dataset[final_dataset['rating_count'] > 30]

# %%
final_dataset.shape
# Out:
# (18812, 9)

# %%
final_dataset
# Out:
#        movieId                                      title  \
# 0            1                                 Toy Story
# 1            2                                   Jumanji
# 2            3                          Grumpier Old Men
# 3            4                         Waiting to Exhale
# 4            5               Father of the Bride Part II
# ...        ...                                        ...
# 48117   289727                   Red, White & Royal Blue
# 48129   290105  You Are So Not Invited to My Bat Mitzvah
# 48132   290213                           The Equalizer 3
# 48142   290407                      No One Will Save You
# 48146   290573                               The Creator
#
#                                             genres  average_rating  \
# 0      Adventure|Animation|Children|Comedy|Fantasy        3.897438
# 1                       Adventure|Children|Fantasy        3.275758
# 2                                   Comedy|Romance        3.139447
# 3                             Comedy|Drama|Romance        2.845331
# 4                                           Comedy        3.059602
# ...                                            ...             ...
# 48117                         Comedy|Drama|Romance        3.500000
# 48129                                       Comedy        3.015152
# 48132                        Action|Crime|Thriller        3.357143
# 48142                       Horror|Sci-Fi|Thriller        2.877193
# 48146                       Action|Sci-Fi|Thriller        3.326087
#
#        rating_count                                               tags  \
# 0             68997  children Disney animation children Disney Disn...
# 1             28904  Robin Williams fantasy Robin Williams time tra...
# 2             13134  comedinha de velhinhos engraÃƒÂ§ada comedinha ...
# 3              2806  characters slurs based on novel or book chick ...
# 4             13154  Fantasy pregnancy remake family Steve Martin s...
# ...             ...                                                ...
# 48117            45  surprisingly good romance gay homosexuality LG...
# 48129            33                      bad acting endearing too long
# 48132            56                                  Denzel Washington
# 48142            57  aliens confusing little dialogue aliens aliens...
# 48146            46  cinematography futuristic lack of coherence no...
#
#        tag_count  year  popularity_score
# 0           1230  1995      93857.951004
# 1            573  1995      34296.017938
# 2             23  1995      15025.909949
# 3             12  1995       2934.176838
# 4             64  1995      14709.917275
# ...          ...   ...               ...
# 48117         17  2023         56.374334
# 48129          3  2023         36.420453
# 48132          1  2023         67.821055
# 48142         32  2023         60.238464
# 48146         28  2023         55.282640
#
# [18812 rows x 9 columns]

# %% [markdown]
# ### Preprocessing
#
# #### we will do onehot encoding for genre and tfidf vectorisation for tags

# %%
from sklearn.preprocessing import OneHotEncoder
import re
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
final_dataset
# Out:
#        movieId                                      title  \
# 0            1                                 Toy Story
# 1            2                                   Jumanji
# 2            3                          Grumpier Old Men
# 3            4                         Waiting to Exhale
# 4            5               Father of the Bride Part II
# ...        ...                                        ...
# 48117   289727                   Red, White & Royal Blue
# 48129   290105  You Are So Not Invited to My Bat Mitzvah
# 48132   290213                           The Equalizer 3
# 48142   290407                      No One Will Save You
# 48146   290573                               The Creator
#
#                                             genres  average_rating  \
# 0      Adventure|Animation|Children|Comedy|Fantasy        3.897438
# 1                       Adventure|Children|Fantasy        3.275758
# 2                                   Comedy|Romance        3.139447
# 3                             Comedy|Drama|Romance        2.845331
# 4                                           Comedy        3.059602
# ...                                            ...             ...
# 48117                         Comedy|Drama|Romance        3.500000
# 48129                                       Comedy        3.015152
# 48132                        Action|Crime|Thriller        3.357143
# 48142                       Horror|Sci-Fi|Thriller        2.877193
# 48146                       Action|Sci-Fi|Thriller        3.326087
#
#        rating_count                                               tags  \
# 0             68997  children Disney animation children Disney Disn...
# 1             28904  Robin Williams fantasy Robin Williams time tra...
# 2             13134  comedinha de velhinhos engraÃƒÂ§ada comedinha ...
# 3              2806  characters slurs based on novel or book chick ...
# 4             13154  Fantasy pregnancy remake family Steve Martin s...
# ...             ...                                                ...
# 48117            45  surprisingly good romance gay homosexuality LG...
# 48129            33                      bad acting endearing too long
# 48132            56                                  Denzel Washington
# 48142            57  aliens confusing little dialogue aliens aliens...
# 48146            46  cinematography futuristic lack of coherence no...
#
#        tag_count  year  popularity_score
# 0           1230  1995      93857.951004
# 1            573  1995      34296.017938
# 2             23  1995      15025.909949
# 3             12  1995       2934.176838
# 4             64  1995      14709.917275
# ...          ...   ...               ...
# 48117         17  2023         56.374334
# 48129          3  2023         36.420453
# 48132          1  2023         67.821055
# 48142         32  2023         60.238464
# 48146         28  2023         55.282640
#
# [18812 rows x 9 columns]

# %%
import pandas as pd
import numpy as np
import re
import pickle

from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from scipy.sparse import hstack

from nltk.corpus import stopwords
from nltk.stem import PorterStemmer

# Load dataset
data = final_dataset

# download stopwords if needed
import nltk
nltk.download('stopwords')


# stopword + stemmer
stop_words = set(stopwords.words('english'))
stemmer = PorterStemmer()
# Out:
# [nltk_data] Downloading package stopwords to C:\Users\KARAN PRATAP
# [nltk_data]     LOHIYA\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# clean tags function
def preprocess_tags(text):

    text = str(text).lower()
    
    text = re.sub('[^a-zA-Z ]',' ',text)

    words = text.split()

    words = [w for w in words if w not in stop_words]

    words = [stemmer.stem(w) for w in words]

    return " ".join(words)


# apply preprocessing
data['tags_clean'] = data['tags'].fillna("").apply(preprocess_tags)

# %%
tfidf = TfidfVectorizer(max_features=5000)

tag_matrix = tfidf.fit_transform(data['tags_clean'])

# %%
# Process genres
data['genres_list'] = data['genres'].apply(lambda x: str(x).split('|'))


# OneHot encode genres
mlb = MultiLabelBinarizer()
genre_matrix = mlb.fit_transform(data['genres_list'])

# %%
# Combine features
feature_matrix = hstack([tag_matrix, genre_matrix])


# Compute similarity
similarity = cosine_similarity(feature_matrix)


# Recommendation function
def recommend(movie_title, top_n=10):

    if movie_title not in data['title'].values:
        return {
            "query_movie": movie_title,
            "recommendations": [],
            "message": "Movie not found"
        }

    idx = data[data['title'] == movie_title].index[0]

    sim_scores = list(enumerate(similarity[idx]))

    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)

    sim_scores = sim_scores[1:50]

    movie_indices = [i[0] for i in sim_scores]

    recommended = data.iloc[movie_indices]

    recommended = recommended.sort_values(
        by='popularity_score',
        ascending=False
    )

    recommended = recommended[['movieId','title','average_rating','rating_count']].head(top_n)

    return {
        "query_movie": movie_title,
        "recommendations": recommended.to_dict(orient="records")
    }


# Example
print(recommend("Toy Story ",5))
# Out:
# {'query_movie': 'Toy Story ', 'recommendations': [{'movieId': 4306, 'title': 'Shrek ', 'average_rating': 3.740491211436073, 'rating_count': 54844}, {'movieId': 4886, 'title': 'Monsters, Inc. ', 'average_rating': 3.8374424363541575, 'rating_count': 46036}, {'movieId': 6377, 'title': 'Finding Nemo ', 'average_rating': 3.8164997398543186, 'rating_count': 46128}, {'movieId': 3114, 'title': 'Toy Story 2 ', 'average_rating': 3.81204295811278, 'rating_count': 32683}, {'movieId': 2355, 'title': "Bug's Life, A ", 'average_rating': 3.5581051765409932, 'rating_count': 26736}]}

# %%
# Example
print(recommend("Waiting to Exhale ",5))
# Out:
# {'query_movie': 'Waiting to Exhale ', 'recommendations': [{'movieId': 539, 'title': 'Sleepless in Seattle ', 'average_rating': 3.510239970120452, 'rating_count': 32129}, {'movieId': 4246, 'title': "Bridget Jones's Diary ", 'average_rating': 3.374563711539494, 'rating_count': 18623}, {'movieId': 69757, 'title': '(500) Days of Summer ', 'average_rating': 3.718751955936659, 'rating_count': 15977}, {'movieId': 5377, 'title': 'About a Boy ', 'average_rating': 3.6268794818413137, 'rating_count': 12969}, {'movieId': 852, 'title': 'Tin Cup ', 'average_rating': 3.177562402852702, 'rating_count': 10937}]}

# %%
# Save objects for deployment
pickle.dump(similarity, open("similarity.pkl","wb"))
pickle.dump(data, open("movies_data.pkl","wb"))
